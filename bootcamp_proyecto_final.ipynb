# %% [markdown]
# Más informacíon https://colab.research.google.com/github/ultralytics/yolov5/blob/master/tutorial.ipynb#scrollTo=7mGmQbAO5pQb

# %% [markdown]
# #Configuración

# %%
# !git clone https://github.com/flaviocondori/yolov5.git  
# %cd yolov5

# %pip install -qr requirements.txt  

import torch
import utils
display = utils.notebook_init()
# Out:
# YOLOv5 🚀 v6.1-302-gf18e369c Python-3.7.13 torch-1.11.0+cu102 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 42.1/78.2 GB disk)

# %%
# %cd /content/
# Out:
# /content

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 640 --batch 6 --epochs 25 --data /content/yolov5/data/custom_data.yaml --weights yolov5s.pt --cache
# Out:
# python3: can't open file 'train.py': [Errno 2] No such file or directory

# %%
# !python detect.py --weights models/last.pt --img 640 --conf 0.25 --source
# Out:
# python3: can't open file 'detect.py': [Errno 2] No such file or directory

# %% [markdown]
# #Test

# %%
# !python detect.py --weights models/last.pt --img 640 --conf 0.82 --iou 0.82 --source /content/yolov5/videos.mp4
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# video 1/1 (9736/14733) /content/yolov5/videos.mp4: 384x640 Done. (0.005s)
# video 1/1 (9737/14733) /content/yolov5/videos.mp4: 384x640 Done. (0.005s)
# video 1/1 (9738/14733) /content/yolov5/videos.mp4: 384x640 Done. (0.008s)
# video 1/1 (9739/14733) /content/yolov5/videos.mp4: 384x640 Done. (0.005s)
# video 1/1 (9740/14733) /content/yolov5/videos.mp4: 384x640 Done. (0.005s)
# video 1/1 (9741/14733) /content/yolov5/videos.mp4: 384x640 Done. (0.005s)
# video 1/1 (9742/14733) /content/yolov5/videos.mp4: 384x640 Done. (0.005s)
# video 1/1 (9743/14733) /content/yolov5/videos.mp4: 384x640 Done. (0.005s)
# video 1/1 (9744/14733) /content/yolov5/videos.mp4: 384x640 Done. (0.005s)
# video 1/1 (9745/14733) /content/yolov5/videos.mp4: 384x640 Done. (0.005s)
# video 1/1 (9746/14733) /content/yolov5/videos.mp4: 384x640 Done. (0.005s)
# video 1/1 (9747/14733) /content/yolov5/videos.mp4: 384x640 Done. (0.005s)
# ...

# %%
# !python detect.py --weights models/last.pt --img 640 --conf 0.80 --iou 0.82 --source /content/yolov5/image.jpeg
# Out:
# detect: weights=['models/last.pt'], source=/content/yolov5/image.jpeg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.8, iou_thres=0.82, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-302-gf18e369c Python-3.7.13 torch-1.11.0+cu102 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/yolov5/image.jpeg: 480x640 1 violence, Done. (0.011s)
# Speed: 0.4ms pre-process, 11.0ms inference, 1.1ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp7

# %%
# !cp /content/yolov5/runs/detect/exp2/video.mp4 /content/drive/MyDrive/YoloCustomTraining/

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
